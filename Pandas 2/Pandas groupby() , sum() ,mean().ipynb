# %%
import pandas as pd

# %%
df=pd.read_csv('nba')
df.groupby(['Team']).mean()
# Out:
#                            Number        Age      Weight        Salary
# Team
# Atlanta Hawks           19.000000  28.200000  221.266667  4.860197e+06
# Boston Celtics          31.866667  24.733333  219.466667  4.181505e+06
# Brooklyn Nets           18.266667  25.600000  215.600000  3.501898e+06
# Charlotte Hornets       17.133333  26.133333  220.400000  5.222728e+06
# Chicago Bulls           19.200000  27.400000  218.933333  5.785559e+06
# Cleveland Cavaliers     14.466667  29.533333  227.866667  7.642049e+06
# Dallas Mavericks        20.000000  29.733333  227.000000  4.746582e+06
# Denver Nuggets          15.266667  25.733333  217.533333  4.294424e+06
# Detroit Pistons         17.266667  26.200000  222.200000  4.477884e+06
# Golden State Warriors   20.866667  27.666667  224.600000  5.924600e+06
# Houston Rockets         14.666667  26.866667  220.333333  5.018868e+06
# Indiana Pacers          18.933333  26.400000  222.266667  4.450122e+06
# ...

# %%
df.groupby(['Team']).mean().sort_values('Salary',ascending=False)
# Out:
#                            Number        Age      Weight        Salary
# Team
# Cleveland Cavaliers     14.466667  29.533333  227.866667  7.642049e+06
# Miami Heat              10.466667  28.933333  218.400000  6.347359e+06
# Los Angeles Clippers    19.533333  29.466667  219.733333  6.323643e+06
# Oklahoma City Thunder   14.000000  27.066667  229.400000  6.251020e+06
# Golden State Warriors   20.866667  27.666667  224.600000  5.924600e+06
# Chicago Bulls           19.200000  27.400000  218.933333  5.785559e+06
# San Antonio Spurs       17.933333  31.600000  223.933333  5.629516e+06
# Memphis Grizzlies       15.555556  28.388889  218.000000  5.467920e+06
# Charlotte Hornets       17.133333  26.133333  220.400000  5.222728e+06
# Washington Wizards      17.600000  27.866667  219.000000  5.088576e+06
# Houston Rockets         14.666667  26.866667  220.333333  5.018868e+06
# Atlanta Hawks           19.000000  28.200000  221.266667  4.860197e+06
# ...

# %%
df.groupby(['Team']).sum()
# Out:
#                         Number    Age  Weight       Salary
# Team
# Atlanta Hawks            285.0  423.0  3319.0   72902950.0
# Boston Celtics           478.0  371.0  3292.0   58541068.0
# Brooklyn Nets            274.0  384.0  3234.0   52528475.0
# Charlotte Hornets        257.0  392.0  3306.0   78340920.0
# Chicago Bulls            288.0  411.0  3284.0   86783378.0
# Cleveland Cavaliers      217.0  443.0  3418.0  106988689.0
# Dallas Mavericks         300.0  446.0  3405.0   71198732.0
# Denver Nuggets           229.0  386.0  3263.0   60121930.0
# Detroit Pistons          259.0  393.0  3333.0   67168263.0
# Golden State Warriors    313.0  415.0  3369.0   88868997.0
# Houston Rockets          220.0  403.0  3305.0   75283021.0
# Indiana Pacers           284.0  396.0  3334.0   66751826.0
# Los Angeles Clippers     293.0  442.0  3296.0   94854640.0
# Los Angeles Lakers       241.0  413.0  3406.0   71770431.0
# Memphis Grizzlies        280.0  511.0  3924.0   76550880.0
# ...

# %%
gk=df.groupby('Team')
gk.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %%
gk.get_group('Oklahoma City Thunder')
# Out:
#       Age       College Height               Name  Number Position  \
# 412  22.0    Pittsburgh    7-0       Steven Adams    12.0        C
# 413  35.0        Kansas   6-10      Nick Collison     4.0       PF
# 414  27.0         Texas    6-9       Kevin Durant    35.0       SF
# 415  32.0     Villanova    6-4         Randy Foye     6.0       SG
# 416  24.0      Stanford    6-7       Josh Huestis    34.0       SF
# 417  26.0           NaN   6-10        Serge Ibaka     9.0       PF
# 418  24.0      Kentucky   6-11        Enes Kanter    11.0        C
# 419  24.0      Michigan   6-10       Mitch McGary    33.0       PF
# 420  38.0      Kentucky   6-10      Nazr Mohammed    13.0        C
# 421  30.0  Georgia Tech    6-5     Anthony Morrow     2.0       SG
# 422  21.0  Murray State    6-3      Cameron Payne    22.0       PG
# 423  24.0      Colorado    6-7     Andre Roberson    21.0       SG
# 424  28.0          Duke    6-8       Kyle Singler     5.0       SF
# ...
