# %%
import pandas as pd

# %%
df=pd.read_csv('nba')
df_s=df.sample(10)
df_s
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 292  Kendrick Perkins    New Orleans Pelicans     5.0        C  31.0   6-10
# 152      Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 404     Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 291   Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0    6-5
# 75       Delon Wright         Toronto Raptors    55.0       PG  24.0    6-5
# 399      Gorgui Dieng  Minnesota Timberwolves     5.0        C  26.0   6-11
# 446    Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 76    Leandro Barbosa   Golden State Warriors    19.0       SG  33.0    6-3
# 383    Darrell Arthur          Denver Nuggets     0.0       PF  28.0    6-9
# 111       Roy Hibbert      Los Angeles Lakers    17.0        C  29.0    7-2
#
#      Weight           College      Salary
# 292   270.0               NaN    947276.0
# 152   161.0            Oregon   2250000.0
# ...

# %%
df_s.sort_index()
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 75       Delon Wright         Toronto Raptors    55.0       PG  24.0    6-5
# 76    Leandro Barbosa   Golden State Warriors    19.0       SG  33.0    6-3
# 111       Roy Hibbert      Los Angeles Lakers    17.0        C  29.0    7-2
# 152      Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 291   Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0    6-5
# 292  Kendrick Perkins    New Orleans Pelicans     5.0        C  31.0   6-10
# 383    Darrell Arthur          Denver Nuggets     0.0       PF  28.0    6-9
# 399      Gorgui Dieng  Minnesota Timberwolves     5.0        C  26.0   6-11
# 404     Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 446    Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
#
#      Weight           College      Salary
# 75    190.0              Utah   1509360.0
# 76    194.0               NaN   2500000.0
# ...
