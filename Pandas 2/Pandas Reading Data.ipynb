# %%
import pandas as pd

# %%
df=pd.read_csv('nba')
df.columns  #returns all the headers in the file.
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df['Name'] #returns value of 'Name' column.
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
df['Name'][0:5]
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
df.Name
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
df[['Name','Team','Age']]
# Out:
#                         Name                    Team   Age
# 0              Avery Bradley          Boston Celtics  25.0
# 1                Jae Crowder          Boston Celtics  25.0
# 2               John Holland          Boston Celtics  27.0
# 3                R.J. Hunter          Boston Celtics  22.0
# 4              Jonas Jerebko          Boston Celtics  29.0
# 5               Amir Johnson          Boston Celtics  29.0
# 6              Jordan Mickey          Boston Celtics  21.0
# 7               Kelly Olynyk          Boston Celtics  25.0
# 8               Terry Rozier          Boston Celtics  22.0
# 9               Marcus Smart          Boston Celtics  22.0
# 10           Jared Sullinger          Boston Celtics  24.0
# 11             Isaiah Thomas          Boston Celtics  27.0
# 12               Evan Turner          Boston Celtics  27.0
# 13               James Young          Boston Celtics  20.0
# 14              Tyler Zeller          Boston Celtics  26.0
# ...
