# %%
from matplotlib import pyplot as plt
# A pie chart refers to a circular graph which are broken down into segments i.e. slices of pie.
# It is basically used to show the percentage or proportional data where each slice of pie represents a category.

# %%
days=[1,2,3,4,5]
sleeping=[4,6,7,2,1]
working=[3,7,9,2,5]
playing=[14,8,9,45,5]
slices=[7,2,2,13]
activities=['Sleeping','Eating','Working','Playing']
plt.pie(slices,labels=activities)
plt.title('Pie Plot')
plt.show()
